# %% [markdown]
# <a href="https://colab.research.google.com/github/JulianaCarvajal/Spaceship_Titanic/blob/main/Gr%C3%A1ficas_relatividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
vx = np.array([ 
    0,
302.7464,
460.3546,
403.774,
465.6402,
5.020272,
85.23638,
78.97775,
89.93633,
44.38906,
35.3016,
59.40937,
42.09486,
0,
0
])

# %%
vy = np.array([
    0,
121.4708,
152.9215,
348.7831,
645.3419,
580.4405,
662.6089,
728.4489,
791.2992,
873.324,
785.5386,
807.2931,
791.3834,
0,
0
 ])

# %%
v2 = np.array([
    0,
299.1569,
339.9337,
445.7319,
614.6081,
675.1164,
782.2614,
929.0373,
1026.206,
995.72,
1102.638,
1251.451,
1330.039,
1456.142,
1549.546
 ])

# %%
a2 = np.array([
    0,
    0,
4027.993,
6739.538,
6333.113,
3264.791,
4585.018,
3761.212,
1161.305,
1790.415,
3914.218,
4606.425,
3179.175,
2957.112,
3100.411 ])

# %%
vx2 = np.array([
    0,
298.5096,
337.0624,
405.4467,
386.5658,
363.6687,
357.5748,
330.8576,
340.7737,
349.6206,
316.4195,
262.2155,
260.4108,
289.2443,
262.655 ])

# %%
vy2 = np.array([
    0,
19.66861,
44.08959,
185.1755,
477.818,
568.7946,
695.7536,
868.1265,
967.9733,
932.3217,
1056.262,
1223.672,
1304.297,
1427.126,
1527.123
])

# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

## Ingreso de los datos


t = np.array([0,0.33,0.66,1,1.33,1.66,2,2.33,2.66,3,3.33,3.66,4,4.33,4.66])
v = np.array([0,326.2062,485.089,533.557,795.7933,580.4622,668.0687,732.7177,796.3937,874.4514,786.3314,809.4761,792.5022,690,600
])
a = np.array([0,0,12524.53,14546.77,5217.439,7574.76,2731.985,2002.709,2193.945,902.5443,163.1519,1219.916,0,0,0
])


plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad')
plt.plot(t,v,"o")
plt.plot(t,v,'b')
plt.title('Video patineta')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad en x')
plt.plot(t,vx,"o",color='magenta')
plt.plot(t,vx,'b',color='magenta')
plt.title('Video patineta')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Aceleración (cm/s^2)')
plt.plot(t,a,"o",)
plt.plot(t,a,'b',)
plt.title('Video patineta')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad en y')
plt.plot(t,vy,"o",)
plt.plot(t,vy,'b',)
plt.title('Video patineta')
plt.show()

print("video 2")

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad ')
plt.plot(t,v2,"o",)
plt.plot(t,v2,'b',)
plt.title('Video piso')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Aceleración (cm/s^2)')
plt.plot(t,a2,"o",)
plt.plot(t,a2,'b',)
plt.title('Video piso')
plt.show()




plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad en x')
plt.plot(t,vx2,"o")
plt.plot(t,vx2,'b' )
plt.title('Video piso')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad en y')
plt.plot(t,vy2,'o-',label = 'Aceleración piso')
plt.title('Video piso')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad (cm/s)')
plt.plot(t,v,"o",)
plt.plot(t,v,'b',)
plt.plot(t,v2,"o",color='magenta')
plt.plot(t,v2,'b',color='magenta')
plt.title('Comparación velocidades')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Aceleración (cm/s^2)')
plt.plot(t,a,"o",label = 'Aceleración patineta')
plt.plot(t,a,'b' , label = 'Aceleración patineta')
plt.plot(t,a2,"o",label = 'Aceleración piso', color='magenta')
plt.plot(t,a2,'b',label = 'Aceleración piso', color='magenta')
plt.title('Comparación aceleraciones')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad en x (cm/s)')
plt.plot(t,vx,"o",label = 'Aceleración patineta')
plt.plot(t,vx,'b' , label = 'Aceleración patineta')
plt.plot(t,vx2,"o",label = 'Aceleración piso', color='magenta')
plt.plot(t,vx2,'b',label = 'Aceleración piso', color='magenta')
plt.title('Comparación velocidades en x')
plt.show()

plt.xlabel('Tiempo (segundos)')
plt.ylabel('Velocidad en y (cm/s)')
plt.plot(t,vy,"o",label = 'Aceleración patineta')
plt.plot(t,vy,'b' , label = 'Aceleración patineta')
plt.plot(t,vy2,"o",label = 'Aceleración piso', color='magenta')
plt.plot(t,vy2,'b',label = 'Aceleración piso', color='magenta')
plt.title('Comparación velocidades en y')
plt.show()
# Out:
# C:\Users\Angie Arenas\AppData\Local\Temp\ipykernel_39896\770223458.py:25: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(t,vx,'b',color='magenta')
# video 2
# C:\Users\Angie Arenas\AppData\Local\Temp\ipykernel_39896\770223458.py:80: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(t,v2,'b',color='magenta')
# C:\Users\Angie Arenas\AppData\Local\Temp\ipykernel_39896\770223458.py:89: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(t,a2,'b',label = 'Aceleración piso', color='magenta')
# C:\Users\Angie Arenas\AppData\Local\Temp\ipykernel_39896\770223458.py:98: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(t,vx2,'b',label = 'Aceleración piso', color='magenta')
# C:\Users\Angie Arenas\AppData\Local\Temp\ipykernel_39896\770223458.py:107: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.0, 0.0, 1.0, 1)). The keyword argument will take precedence.
#   plt.plot(t,vy2,'b',label = 'Aceleración piso', color='magenta')
